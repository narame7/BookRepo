# %%
import pandas as pd

# %%
order = pd.read_csv('data/Daily_Demand_Forecasting_Orders.csv', delimiter=';')

# %%
banking_orders_2 = order['Banking orders (2)']

# %%
import statsmodels.graphics.tsaplots as sgt 
import matplotlib.pyplot as plt

# %%
plt.plot(banking_orders_2)
sgt.plot_pacf(banking_orders_2, method="ywm")

plt.show()

# %%
from statsmodels.tsa import ar_model

search = ar_model.ar_select_order(endog=banking_orders_2, maxlag=8, ic="aic", glob=True)
search.ar_lags
# Out:
# [1, 2, 3]

# %%
mod = sm.tsa.arima.ARIMA(banking_orders_2, order=(3, 0, 0))
res = mod.fit()
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     Banking orders (2)   No. Observations:                   60
# Model:                 ARIMA(3, 0, 0)   Log Likelihood                -717.601
# Date:                Thu, 20 Apr 2023   AIC                           1445.202
# Time:                        03:56:22   BIC                           1455.674
# Sample:                             0   HQIC                          1449.298
#                                  - 60
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        7.94e+04   3631.436     21.865      0.000    7.23e+04    8.65e+04
# ar.L1         -0.1353      0.181     -0.746      0.456      -0.491       0.220
# ar.L2         -0.2016      0.111     -1.810      0.070      -0.420       0.017
# ar.L3         -0.3191      0.157     -2.033      0.042      -0.627      -0.011
# sigma2       1.27e+09      0.022   5.65e+10      0.000    1.27e+09    1.27e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 5.12
# Prob(Q):                              0.97   Prob(JB):                         0.08
# Heteroskedasticity (H):               0.52   Skew:                             0.69
# Prob(H) (two-sided):                  0.16   Kurtosis:                         3.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.59e+25. Standard errors may be unstable.

# %%
mod = sm.tsa.arima.ARIMA(banking_orders_2, order=(3, 0, 0), enforce_stationarity=False)
with mod.fix_params({'ar.L1': 0}):
    res = mod.fit()
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     Banking orders (2)   No. Observations:                   60
# Model:                 ARIMA(3, 0, 0)   Log Likelihood                -679.043
# Date:                Thu, 20 Apr 2023   AIC                           1366.087
# Time:                        03:56:27   BIC                           1374.259
# Sample:                             0   HQIC                          1369.263
#                                  - 60
# Covariance Type:                  opg
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           7.94e+04   3680.484     21.574      0.000    7.22e+04    8.66e+04
# ar.L1 (fixed)          0        nan        nan        nan         nan         nan
# ar.L2            -0.1095      0.120     -0.910      0.363      -0.345       0.126
# ar.L3            -0.2634      0.168     -1.570      0.116      -0.592       0.065
# sigma2          1.27e+09      0.031   4.16e+10      0.000    1.27e+09    1.27e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.18   Jarque-Bera (JB):                 6.48
# Prob(Q):                              0.28   Prob(JB):                         0.04
# Heteroskedasticity (H):               0.52   Skew:                             0.81
# Prob(H) (two-sided):                  0.16   Kurtosis:                         3.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.18e+26. Standard errors may be unstable.

# %%
sgt.plot_pacf(res.resid, method="ywm")
plt.show()

# %%
sm.stats.acorr_ljungbox(res.resid, lags=[10], model_df=3, return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  8.838425   0.264466

# %%
banking_orders_2.plot()
res.fittedvalues.plot()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(banking_orders_2.diff(), res.fittedvalues.diff())

# %% [markdown]
# # Moving Average Model

# %%
plt.plot(banking_orders_2)
sgt.plot_acf(banking_orders_2, adjusted=True)

plt.show()

# %%
mod = sm.tsa.arima.ARIMA(banking_orders_2, order=(0, 0, 9), enforce_invertibility=False)
with mod.fix_params({'ma.L1': 0, 'ma.L2': 0, 'ma.L4': 0, 'ma.L5': 0, 'ma.L6': 0, 'ma.L7': 0, 'ma.L8': 0}):
    res = mod.fit()
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     Banking orders (2)   No. Observations:                   60
# Model:                 ARIMA(0, 0, 9)   Log Likelihood                -720.150
# Date:                Thu, 20 Apr 2023   AIC                           1448.300
# Time:                        04:43:29   BIC                           1456.677
# Sample:                             0   HQIC                          1451.577
#                                  - 60
# Covariance Type:                  opg
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           7.94e+04   2085.761     38.068      0.000    7.53e+04    8.35e+04
# ma.L1 (fixed)          0        nan        nan        nan         nan         nan
# ma.L2 (fixed)          0        nan        nan        nan         nan         nan
# ma.L3            -0.4838      0.111     -4.373      0.000      -0.701      -0.267
# ma.L4 (fixed)          0        nan        nan        nan         nan         nan
# ma.L5 (fixed)          0        nan        nan        nan         nan         nan
# ma.L6 (fixed)          0        nan        nan        nan         nan         nan
# ma.L7 (fixed)          0        nan        nan        nan         nan         nan
# ma.L8 (fixed)          0        nan        nan        nan         nan         nan
# ma.L9            -0.0093      0.093     -0.101      0.920      -0.191       0.172
# sigma2          9.33e+08      0.011   8.15e+10      0.000    9.33e+08    9.33e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.89   Jarque-Bera (JB):                 3.49
# Prob(Q):                              0.35   Prob(JB):                         0.17
# Heteroskedasticity (H):               0.55   Skew:                             0.59
# Prob(H) (two-sided):                  0.19   Kurtosis:                         3.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.21e+26. Standard errors may be unstable.

# %%
sm.stats.acorr_ljungbox(res.resid, lags=[10], model_df=3, return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  7.470344   0.381601

# %%
res.fittedvalues
# Out:
# 0      79401.483339
# 1      79401.483339
# 2      79401.483339
# 3      36669.653446
# 4      75458.143639
# 5     102175.357763
# 6      64856.347511
# 7     106687.251005
# 8     104409.842296
# 9      86527.248507
# 10    103175.921464
# 11     80290.624312
# 12     81100.624566
# 13     77247.012761
# 14    100911.682367
# 15     80979.260452
# 16     60583.353189
# 17     79342.706377
# 18     88233.085675
# 19     64259.799513
# 20    104701.842832
# 21     46832.035757
# 22     72199.326275
# 23    115597.903043
# 24     79106.596936
# 25     69191.735554
# 26     70344.384297
# 27     90151.273348
# 28     80031.329959
# 29     91122.143737
# 30    101753.417748
# 31     40825.917387
# 32     92951.739250
# 33     67585.624950
# 34     74768.489903
# 35     38842.786323
# 36     81713.875406
# 37     90273.110119
# 38     68660.793439
# 39     52889.397999
# 40     90694.106735
# 41     85332.707942
# 42     63720.468855
# 43     41700.476495
# 44     85232.520986
# 45     75763.322520
# 46     81099.141998
# 47     95554.389105
# 48     65646.874167
# 49     89247.963824
# 50     84838.114821
# 51     80245.115576
# 52     93815.233508
# 53     46182.292677
# 54     74565.525372
# 55    100975.106149
# 56     91409.782418
# 57     83950.297142
# 58     66475.221272
# 59     80544.397422
# dtype: float64

# %%
# ArmaProcess로 모형 생성하고 nobs 만큼 샘플 생성
def gen_arma_samples (ar,ma,nobs):
    arma_model   = ArmaProcess(ar=ar, ma=ma)        # 모형 정의
    arma_samples = arma_model.generate_sample(nobs) # 샘플 생성
    return arma_samples

# %%
test = gen_arma_samples(ar = [2], ma = [1], nobs = 1000)

# %%
plt.plot(test)

# %%
mod = sm.tsa.arima.ARIMA(test, order=(1, 0, 1))
res = mod.fit()
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -332.433
# Date:                Thu, 20 Apr 2023   AIC                            672.866
# Time:                        05:04:57   BIC                            692.497
# Sample:                             0   HQIC                           680.327
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.011      0.149      0.882      -0.020       0.023
# ar.L1          0.0093      1.832      0.005      0.996      -3.582       3.601
# ma.L1          0.0078      1.831      0.004      0.997      -3.581       3.597
# sigma2         0.1138      0.005     21.880      0.000       0.104       0.124
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.44
# Prob(Q):                              1.00   Prob(JB):                         0.80
# Heteroskedasticity (H):               1.17   Skew:                             0.03
# Prob(H) (two-sided):                  0.16   Kurtosis:                         2.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
sgt.plot_acf(res.resid, adjusted=True)
sgt.plot_pacf(res.resid, method="ywm")
plt.show()

# %%
mod = sm.tsa.arima.ARIMA(test, order=(2, 0, 1))
res = mod.fit()
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(3, 0, 1)   Log Likelihood                -331.727
# Date:                Thu, 20 Apr 2023   AIC                            675.454
# Time:                        05:05:18   BIC                            704.900
# Sample:                             0   HQIC                           686.645
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.011      0.154      0.878      -0.019       0.022
# ar.L1          0.0085      0.883      0.010      0.992      -1.722       1.739
# ar.L2         -0.0004      0.035     -0.011      0.991      -0.070       0.069
# ar.L3         -0.0376      0.034     -1.113      0.266      -0.104       0.029
# ma.L1          0.0087      0.883      0.010      0.992      -1.723       1.740
# sigma2         0.1137      0.005     21.872      0.000       0.103       0.124
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.25
# Prob(Q):                              1.00   Prob(JB):                         0.88
# Heteroskedasticity (H):               1.16   Skew:                             0.02
# Prob(H) (two-sided):                  0.17   Kurtosis:                         2.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
sgt.plot_acf(res.resid, adjusted=True)
sgt.plot_pacf(res.resid, method="ywm")
plt.show()
