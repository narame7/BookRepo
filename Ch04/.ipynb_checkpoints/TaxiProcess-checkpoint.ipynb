# %%
import numpy as np

# %%
def taxi_id_number(num_taxis):
    arr = np.arange(num_taxis)
    np.random.shuffle(arr)
    for i in range(num_taxis):
        yield arr[i]

# %%
ids = taxi_id_number(10)
print(next(ids))
print(next(ids))
print(next(ids))
# Out:
# 2
# 6
# 3

# %%
def shift_info():
    start_times_and_freqs = [(0, 8), (8, 30), (16, 15)]
    indices = np.arange(len(start_times_and_freqs))
    while True:
        idx = np.random.choice(indices, p = [0.25, 0.5, 0.25])
        start = start_times_and_freqs[idx]
        yield (start[0], start[0] + 7.5, start[1])

# %%
def taxi_process(taxi_id_generator, shift_info_generator):
    taxi_id = next(taxi_id_generator)
    shift_start, shift_end, shift_mean_trips = next(shift_info_generator)
    actual_trips = round(np.random.normal(loc = shift_mean_trips, scale = 2))
    average_trip_time = 6.5 / shift_mean_trips * 60
    
    ##평균 운행 시간을 분 단위로 변환한다
    between_events_time = 1.0 / (shift_mean_trips - 1) * 60
    ##이 도시는 매우 효율적이라 모든 택시가 거의 항상 사용된다
    time = shift_start
    yield TimePoint(taxi_id, 'start_shift', time)
    deltaT = np.random.poisson(between_events_time) / 60
    time += deltaT
    for i in range(actual_trips):
        yield TimePoint(taxi_id, 'pick up', time)
        deltaT = np.random.poisson(average_trip_time) / 60
        time += deltaT
        yield TimePoint(taxi_id, 'drop off', time)
        deltaT = np.random.poisson(between_events_time) / 60
        time += deltaT
    deltaT = np.random.poisson(between_events_time) / 60
    time += deltaT
    yield TimePoint(taxi_id, 'end shift ', time)

# %%
from dataclasses import dataclass

@dataclass
class TimePoint:
    taxi_id : int
    name : str
    time : float
    
    def __lt__(self, other):
        return self.time < other.time

# %%
import queue

class Simulator:
    def __init__(self, num_taxis):
        self._time_points = queue.PriorityQueue()
        taxi_id_generator = taxi_id_number(num_taxis)
        shift_info_generator = shift_info()
        self._taxis = [taxi_process(taxi_id_generator, shift_info_generator) for i in range(num_taxis)]
        self._prepare_run()
        
    def _prepare_run(self):
        for t in self._taxis:
            while True:
                try:
                    e = next(t)
                    self._time_points.put(e)
                except:
                    break
                    
    def run(self):
        sim_time = 0
        while sim_time < 24:
            if self._time_points.empty():
                break
            p = self._time_points.get()
            sim_time = p.time
            print(p)

# %%
sim = Simulator(10)
sim.run()
# Out:
# TimePoint(taxi_id=737, name='start_shift', time=0)
# TimePoint(taxi_id=856, name='start_shift', time=0)
# TimePoint(taxi_id=407, name='start_shift', time=0)
# TimePoint(taxi_id=279, name='start_shift', time=0)
# TimePoint(taxi_id=12, name='start_shift', time=0)
# TimePoint(taxi_id=725, name='start_shift', time=0)
# TimePoint(taxi_id=406, name='start_shift', time=0)
# TimePoint(taxi_id=46, name='start_shift', time=0)
# TimePoint(taxi_id=366, name='start_shift', time=0)
# TimePoint(taxi_id=95, name='start_shift', time=0)
# TimePoint(taxi_id=573, name='start_shift', time=0)
# TimePoint(taxi_id=4, name='start_shift', time=0)
# TimePoint(taxi_id=707, name='start_shift', time=0)
# TimePoint(taxi_id=961, name='start_shift', time=0)
# TimePoint(taxi_id=75, name='start_shift', time=0)
# TimePoint(taxi_id=501, name='start_shift', time=0)
# TimePoint(taxi_id=207, name='start_shift', time=0)
# TimePoint(taxi_id=199, name='start_shift', time=0)
# TimePoint(taxi_id=511, name='start_shift', time=0)
# TimePoint(taxi_id=827, name='start_shift', time=0)
# TimePoint(taxi_id=310, name='start_shift', time=0)
# TimePoint(taxi_id=589, name='start_shift', time=0)
# TimePoint(taxi_id=18, name='start_shift', time=0)
# TimePoint(taxi_id=127, name='start_shift', time=0)
# TimePoint(taxi_id=641, name='start_shift', time=0)
# TimePoint(taxi_id=877, name='start_shift', time=0)
# TimePoint(taxi_id=117, name='start_shift', time=0)
# TimePoint(taxi_id=653, name='start_shift', time=0)
# TimePoint(taxi_id=455, name='start_shift', time=0)
# TimePoint(taxi_id=408, name='start_shift', time=0)
# TimePoint(taxi_id=538, name='start_shift', time=0)
# TimePoint(taxi_id=949, name='start_shift', time=0)
# TimePoint(taxi_id=469, name='start_shift', time=0)
# TimePoint(taxi_id=320, name='start_shift', time=0)
# TimePoint(taxi_id=215, name='start_shift', time=0)
# TimePoint(taxi_id=863, name='start_shift', time=0)
# TimePoint(taxi_id=862, name='start_shift', time=0)
# TimePoint(taxi_id=563, name='start_shift', time=0)
# TimePoint(taxi_id=934, name='start_shift', time=0)
# TimePoint(taxi_id=593, name='start_shift', time=0)
# TimePoint(taxi_id=695, name='start_shift', time=0)
# TimePoint(taxi_id=354, name='start_shift', time=0)
# TimePoint(taxi_id=76, name='start_shift', time=0)
# TimePoint(taxi_id=461, name='start_shift', time=0)
# TimePoint(taxi_id=643, name='start_shift', time=0)
# TimePoint(taxi_id=703, name='start_shift', time=0)
# TimePoint(taxi_id=578, name='start_shift', time=0)
# TimePoint(taxi_id=302, name='start_shift', time=0)
# TimePoint(taxi_id=428, name='start_shift', time=0)
# TimePoint(taxi_id=192, name='start_shift', time=0)
# TimePoint(taxi_id=67, name='start_shift', time=0)
# TimePoint(taxi_id=997, name='start_shift', time=0)
# TimePoint(taxi_id=42, name='start_shift', time=0)
# TimePoint(taxi_id=706, name='start_shift', time=0)
# TimePoint(taxi_id=213, name='start_shift', time=0)
# TimePoint(taxi_id=128, name='start_shift', time=0)
# TimePoint(taxi_id=890, name='start_shift', time=0)
# TimePoint(taxi_id=244, name='start_shift', time=0)
# TimePoint(taxi_id=778, name='start_shift', time=0)
# TimePoint(taxi_id=439, name='start_shift', time=0)
# TimePoint(taxi_id=577, name='start_shift', time=0)
# TimePoint(taxi_id=333, name='start_shift', time=0)
# TimePoint(taxi_id=71, name='start_shift', time=0)
# TimePoint(taxi_id=332, name='start_shift', time=0)
# TimePoint(taxi_id=521, name='start_shift', time=0)
# TimePoint(taxi_id=826, name='start_shift', time=0)
# TimePoint(taxi_id=868, name='start_shift', time=0)
# TimePoint(taxi_id=676, name='start_shift', time=0)
# TimePoint(taxi_id=3, name='start_shift', time=0)
# TimePoint(taxi_id=27, name='start_shift', time=0)
# TimePoint(taxi_id=597, name='start_shift', time=0)
# TimePoint(taxi_id=691, name='start_shift', time=0)
# TimePoint(taxi_id=344, name='start_shift', time=0)
# TimePoint(taxi_id=757, name='start_shift', time=0)
# TimePoint(taxi_id=275, name='start_shift', time=0)
# TimePoint(taxi_id=184, name='start_shift', time=0)
# TimePoint(taxi_id=122, name='start_shift', time=0)
# TimePoint(taxi_id=478, name='start_shift', time=0)
# TimePoint(taxi_id=995, name='start_shift', time=0)
# TimePoint(taxi_id=426, name='start_shift', time=0)
# TimePoint(taxi_id=689, name='start_shift', time=0)
# TimePoint(taxi_id=130, name='start_shift', time=0)
# TimePoint(taxi_id=853, name='start_shift', time=0)
# TimePoint(taxi_id=315, name='start_shift', time=0)
# TimePoint(taxi_id=503, name='start_shift', time=0)
# TimePoint(taxi_id=157, name='start_shift', time=0)
# TimePoint(taxi_id=80, name='start_shift', time=0)
# TimePoint(taxi_id=702, name='start_shift', time=0)
# TimePoint(taxi_id=141, name='start_shift', time=0)
# TimePoint(taxi_id=129, name='start_shift', time=0)
# TimePoint(taxi_id=957, name='start_shift', time=0)
# TimePoint(taxi_id=789, name='start_shift', time=0)
# TimePoint(taxi_id=991, name='start_shift', time=0)
# TimePoint(taxi_id=151, name='start_shift', time=0)
# TimePoint(taxi_id=55, name='start_shift', time=0)
# TimePoint(taxi_id=794, name='start_shift', time=0)
# TimePoint(taxi_id=663, name='start_shift', time=0)
# TimePoint(taxi_id=493, name='start_shift', time=0)
# TimePoint(taxi_id=107, name='start_shift', time=0)
# TimePoint(taxi_id=293, name='start_shift', time=0)
# TimePoint(taxi_id=650, name='start_shift', time=0)
# TimePoint(taxi_id=714, name='start_shift', time=0)
# TimePoint(taxi_id=914, name='start_shift', time=0)
# TimePoint(taxi_id=211, name='start_shift', time=0)
# TimePoint(taxi_id=899, name='start_shift', time=0)
# TimePoint(taxi_id=101, name='start_shift', time=0)
# TimePoint(taxi_id=562, name='start_shift', time=0)
# TimePoint(taxi_id=289, name='start_shift', time=0)
# TimePoint(taxi_id=22, name='start_shift', time=0)
# TimePoint(taxi_id=242, name='start_shift', time=0)
# TimePoint(taxi_id=214, name='start_shift', time=0)
# TimePoint(taxi_id=545, name='start_shift', time=0)
# TimePoint(taxi_id=19, name='start_shift', time=0)
# TimePoint(taxi_id=425, name='start_shift', time=0)
# TimePoint(taxi_id=132, name='start_shift', time=0)
# TimePoint(taxi_id=385, name='start_shift', time=0)
# TimePoint(taxi_id=90, name='start_shift', time=0)
# TimePoint(taxi_id=883, name='start_shift', time=0)
# TimePoint(taxi_id=964, name='start_shift', time=0)
# TimePoint(taxi_id=422, name='start_shift', time=0)
# TimePoint(taxi_id=554, name='start_shift', time=0)
# TimePoint(taxi_id=605, name='start_shift', time=0)
# TimePoint(taxi_id=361, name='start_shift', time=0)
# TimePoint(taxi_id=633, name='start_shift', time=0)
# TimePoint(taxi_id=970, name='start_shift', time=0)
# TimePoint(taxi_id=322, name='start_shift', time=0)
# TimePoint(taxi_id=448, name='start_shift', time=0)
# TimePoint(taxi_id=177, name='start_shift', time=0)
# TimePoint(taxi_id=781, name='start_shift', time=0)
# TimePoint(taxi_id=613, name='start_shift', time=0)
# TimePoint(taxi_id=125, name='start_shift', time=0)
# TimePoint(taxi_id=784, name='start_shift', time=0)
# TimePoint(taxi_id=690, name='start_shift', time=0)
# TimePoint(taxi_id=348, name='start_shift', time=0)
# TimePoint(taxi_id=782, name='start_shift', time=0)
# TimePoint(taxi_id=805, name='start_shift', time=0)
# TimePoint(taxi_id=109, name='start_shift', time=0)
# TimePoint(taxi_id=1, name='start_shift', time=0)
# TimePoint(taxi_id=175, name='start_shift', time=0)
# TimePoint(taxi_id=470, name='start_shift', time=0)
# TimePoint(taxi_id=301, name='start_shift', time=0)
# TimePoint(taxi_id=622, name='start_shift', time=0)
# TimePoint(taxi_id=915, name='start_shift', time=0)
# TimePoint(taxi_id=938, name='start_shift', time=0)
# TimePoint(taxi_id=352, name='start_shift', time=0)
# TimePoint(taxi_id=456, name='start_shift', time=0)
# TimePoint(taxi_id=680, name='start_shift', time=0)
# TimePoint(taxi_id=586, name='start_shift', time=0)
# TimePoint(taxi_id=796, name='start_shift', time=0)
# TimePoint(taxi_id=910, name='start_shift', time=0)
# TimePoint(taxi_id=972, name='start_shift', time=0)
# TimePoint(taxi_id=38, name='start_shift', time=0)
# TimePoint(taxi_id=69, name='start_shift', time=0)
# TimePoint(taxi_id=195, name='start_shift', time=0)
# TimePoint(taxi_id=241, name='start_shift', time=0)
# TimePoint(taxi_id=182, name='start_shift', time=0)
# TimePoint(taxi_id=93, name='start_shift', time=0)
# TimePoint(taxi_id=391, name='start_shift', time=0)
# TimePoint(taxi_id=950, name='start_shift', time=0)
# TimePoint(taxi_id=741, name='start_shift', time=0)
# TimePoint(taxi_id=569, name='start_shift', time=0)
# TimePoint(taxi_id=304, name='start_shift', time=0)
# TimePoint(taxi_id=399, name='start_shift', time=0)
# TimePoint(taxi_id=701, name='start_shift', time=0)
# TimePoint(taxi_id=247, name='start_shift', time=0)
# TimePoint(taxi_id=516, name='start_shift', time=0)
# TimePoint(taxi_id=397, name='start_shift', time=0)
# TimePoint(taxi_id=869, name='start_shift', time=0)
# TimePoint(taxi_id=721, name='start_shift', time=0)
# TimePoint(taxi_id=435, name='start_shift', time=0)
# TimePoint(taxi_id=465, name='start_shift', time=0)
# TimePoint(taxi_id=533, name='start_shift', time=0)
# TimePoint(taxi_id=371, name='start_shift', time=0)
# TimePoint(taxi_id=327, name='start_shift', time=0)
# TimePoint(taxi_id=733, name='start_shift', time=0)
# TimePoint(taxi_id=246, name='start_shift', time=0)
# TimePoint(taxi_id=506, name='start_shift', time=0)
# TimePoint(taxi_id=520, name='start_shift', time=0)
# TimePoint(taxi_id=811, name='start_shift', time=0)
# TimePoint(taxi_id=284, name='start_shift', time=0)
# TimePoint(taxi_id=263, name='start_shift', time=0)
# TimePoint(taxi_id=656, name='start_shift', time=0)
# TimePoint(taxi_id=518, name='start_shift', time=0)
# TimePoint(taxi_id=872, name='start_shift', time=0)
# TimePoint(taxi_id=814, name='start_shift', time=0)
# TimePoint(taxi_id=343, name='start_shift', time=0)
# TimePoint(taxi_id=400, name='start_shift', time=0)
# TimePoint(taxi_id=565, name='start_shift', time=0)
# TimePoint(taxi_id=916, name='start_shift', time=0)
# TimePoint(taxi_id=340, name='start_shift', time=0)
# TimePoint(taxi_id=801, name='start_shift', time=0)
# TimePoint(taxi_id=430, name='start_shift', time=0)
# TimePoint(taxi_id=112, name='start_shift', time=0)
# TimePoint(taxi_id=163, name='start_shift', time=0)
# TimePoint(taxi_id=867, name='start_shift', time=0)
# TimePoint(taxi_id=45, name='start_shift', time=0)
# TimePoint(taxi_id=812, name='start_shift', time=0)
# TimePoint(taxi_id=909, name='start_shift', time=0)
# TimePoint(taxi_id=131, name='start_shift', time=0)
# TimePoint(taxi_id=287, name='start_shift', time=0)
# TimePoint(taxi_id=790, name='start_shift', time=0)
# TimePoint(taxi_id=222, name='start_shift', time=0)
# TimePoint(taxi_id=142, name='start_shift', time=0)
# TimePoint(taxi_id=418, name='start_shift', time=0)
# TimePoint(taxi_id=449, name='start_shift', time=0)
# TimePoint(taxi_id=7, name='start_shift', time=0)
# TimePoint(taxi_id=384, name='start_shift', time=0)
# TimePoint(taxi_id=743, name='start_shift', time=0)
# TimePoint(taxi_id=846, name='start_shift', time=0)
# TimePoint(taxi_id=64, name='start_shift', time=0)
# TimePoint(taxi_id=120, name='start_shift', time=0)
# TimePoint(taxi_id=560, name='start_shift', time=0)
# TimePoint(taxi_id=274, name='start_shift', time=0)
# TimePoint(taxi_id=270, name='start_shift', time=0)
# TimePoint(taxi_id=367, name='start_shift', time=0)
# TimePoint(taxi_id=526, name='start_shift', time=0)
# TimePoint(taxi_id=488, name='start_shift', time=0)
# TimePoint(taxi_id=920, name='start_shift', time=0)
# TimePoint(taxi_id=967, name='start_shift', time=0)
# TimePoint(taxi_id=561, name='start_shift', time=0)
# TimePoint(taxi_id=592, name='start_shift', time=0)
# TimePoint(taxi_id=684, name='start_shift', time=0)
# TimePoint(taxi_id=59, name='start_shift', time=0)
# TimePoint(taxi_id=541, name='start_shift', time=0)
# TimePoint(taxi_id=174, name='start_shift', time=0)
# TimePoint(taxi_id=694, name='start_shift', time=0)
# TimePoint(taxi_id=208, name='start_shift', time=0)
# TimePoint(taxi_id=34, name='start_shift', time=0)
# TimePoint(taxi_id=833, name='start_shift', time=0)
# TimePoint(taxi_id=816, name='start_shift', time=0)
# TimePoint(taxi_id=708, name='start_shift', time=0)
# TimePoint(taxi_id=937, name='start_shift', time=0)
# TimePoint(taxi_id=874, name='start_shift', time=0)
# TimePoint(taxi_id=73, name='start_shift', time=0)
# TimePoint(taxi_id=717, name='start_shift', time=0)
# TimePoint(taxi_id=679, name='start_shift', time=0)
# TimePoint(taxi_id=876, name='start_shift', time=0)
# TimePoint(taxi_id=704, name='start_shift', time=0)
# TimePoint(taxi_id=759, name='start_shift', time=0)
# TimePoint(taxi_id=51, name='start_shift', time=0)
# TimePoint(taxi_id=145, name='start_shift', time=0)
# TimePoint(taxi_id=603, name='start_shift', time=0)
# TimePoint(taxi_id=368, name='start_shift', time=0)
# TimePoint(taxi_id=884, name='start_shift', time=0)
# TimePoint(taxi_id=786, name='start_shift', time=0)
# TimePoint(taxi_id=668, name='start_shift', time=0)
# TimePoint(taxi_id=752, name='start_shift', time=0)
# TimePoint(taxi_id=382, name='start_shift', time=0)
# TimePoint(taxi_id=66, name='start_shift', time=0)
# TimePoint(taxi_id=457, name='start_shift', time=0)
# TimePoint(taxi_id=172, name='start_shift', time=0)
# TimePoint(taxi_id=572, name='start_shift', time=0)
# TimePoint(taxi_id=161, name='start_shift', time=0)
# TimePoint(taxi_id=547, name='start_shift', time=0)
# TimePoint(taxi_id=693, name='start_shift', time=0)
# TimePoint(taxi_id=880, name='start_shift', time=0)
# TimePoint(taxi_id=638, name='start_shift', time=0)
# TimePoint(taxi_id=431, name='start_shift', time=0)
# TimePoint(taxi_id=590, name='start_shift', time=0)
# TimePoint(taxi_id=342, name='start_shift', time=0)
# TimePoint(taxi_id=726, name='start_shift', time=0)
# TimePoint(taxi_id=652, name='start_shift', time=0)
# TimePoint(taxi_id=297, name='start_shift', time=0)
# TimePoint(taxi_id=319, name='start_shift', time=0)
# TimePoint(taxi_id=162, name='start_shift', time=0)
# TimePoint(taxi_id=356, name='start_shift', time=0)
# TimePoint(taxi_id=17, name='start_shift', time=0)
# TimePoint(taxi_id=700, name='start_shift', time=0)
# TimePoint(taxi_id=780, name='start_shift', time=0)
# TimePoint(taxi_id=369, name='start_shift', time=0)
# TimePoint(taxi_id=806, name='start_shift', time=0)
# TimePoint(taxi_id=829, name='start_shift', time=0)
# TimePoint(taxi_id=751, name='start_shift', time=0)
# TimePoint(taxi_id=686, name='start_shift', time=0)
# TimePoint(taxi_id=716, name='start_shift', time=0)
# TimePoint(taxi_id=462, name='start_shift', time=0)
# TimePoint(taxi_id=712, name='start_shift', time=0)
# TimePoint(taxi_id=118, name='start_shift', time=0)
# TimePoint(taxi_id=447, name='start_shift', time=0)
# TimePoint(taxi_id=244, name='pick up', time=0.03333333333333333)
# TimePoint(taxi_id=407, name='pick up', time=0.05)
# TimePoint(taxi_id=71, name='pick up', time=0.05)
# TimePoint(taxi_id=322, name='pick up', time=0.05)
# TimePoint(taxi_id=93, name='pick up', time=0.05)
# TimePoint(taxi_id=222, name='pick up', time=0.05)
# TimePoint(taxi_id=120, name='pick up', time=0.05)
# TimePoint(taxi_id=64, name='pick up', time=0.05)
# TimePoint(taxi_id=34, name='pick up', time=0.05)
# TimePoint(taxi_id=122, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=348, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=680, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=520, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=287, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=967, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=884, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=668, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=297, name='pick up', time=0.06666666666666667)
# TimePoint(taxi_id=406, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=199, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=703, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=778, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=890, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=868, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=757, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=853, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=426, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=90, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=586, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=182, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=391, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=915, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=533, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=45, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=506, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=846, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=560, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=488, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=920, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=73, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=457, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=342, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=172, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=686, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=751, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=118, name='pick up', time=0.08333333333333333)
# TimePoint(taxi_id=207, name='pick up', time=0.1)
# TimePoint(taxi_id=455, name='pick up', time=0.1)
# TimePoint(taxi_id=302, name='pick up', time=0.1)
# TimePoint(taxi_id=461, name='pick up', time=0.1)
# TimePoint(taxi_id=213, name='pick up', time=0.1)
# TimePoint(taxi_id=67, name='pick up', time=0.1)
# TimePoint(taxi_id=333, name='pick up', time=0.1)
# TimePoint(taxi_id=521, name='pick up', time=0.1)
# TimePoint(taxi_id=130, name='pick up', time=0.1)
# TimePoint(taxi_id=714, name='pick up', time=0.1)
# TimePoint(taxi_id=289, name='pick up', time=0.1)
# TimePoint(taxi_id=19, name='pick up', time=0.1)
# TimePoint(taxi_id=242, name='pick up', time=0.1)
# TimePoint(taxi_id=214, name='pick up', time=0.1)
# TimePoint(taxi_id=175, name='pick up', time=0.1)
# TimePoint(taxi_id=304, name='pick up', time=0.1)
# TimePoint(taxi_id=465, name='pick up', time=0.1)
# TimePoint(taxi_id=872, name='pick up', time=0.1)
# TimePoint(taxi_id=812, name='pick up', time=0.1)
# TimePoint(taxi_id=163, name='pick up', time=0.1)
# TimePoint(taxi_id=270, name='pick up', time=0.1)
# TimePoint(taxi_id=208, name='pick up', time=0.1)
# TimePoint(taxi_id=937, name='pick up', time=0.1)
# TimePoint(taxi_id=717, name='pick up', time=0.1)
# TimePoint(taxi_id=733, name='pick up', time=0.1)
# TimePoint(taxi_id=704, name='pick up', time=0.1)
# TimePoint(taxi_id=880, name='pick up', time=0.1)
# TimePoint(taxi_id=693, name='pick up', time=0.1)
# TimePoint(taxi_id=716, name='pick up', time=0.1)
# TimePoint(taxi_id=641, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=408, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=863, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=215, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=934, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=695, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=76, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=439, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=676, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=275, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=702, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=789, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=663, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=883, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=970, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=613, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=782, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=690, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=622, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=38, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=69, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=569, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=327, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=811, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=867, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=367, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=592, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=833, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=874, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=752, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=547, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=572, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=700, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=17, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=712, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=447, name='pick up', time=0.11666666666666667)
# TimePoint(taxi_id=725, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=573, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=75, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=95, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=961, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=18, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=469, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=320, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=192, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=997, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=856, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=27, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=691, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=577, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=141, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=315, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=55, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=151, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=293, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=107, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=493, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=545, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=101, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=132, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=385, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=422, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=554, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=361, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=125, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=796, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=241, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=741, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=399, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=397, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=340, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=541, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=694, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=816, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=679, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=145, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=51, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=382, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=726, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=356, name='pick up', time=0.13333333333333333)
# TimePoint(taxi_id=578, name='pick up', time=0.15)
# TimePoint(taxi_id=128, name='pick up', time=0.15)
# TimePoint(taxi_id=332, name='pick up', time=0.15)
# TimePoint(taxi_id=826, name='pick up', time=0.15)
# TimePoint(taxi_id=3, name='pick up', time=0.15)
# TimePoint(taxi_id=157, name='pick up', time=0.15)
# TimePoint(taxi_id=995, name='pick up', time=0.15)
# TimePoint(taxi_id=177, name='pick up', time=0.15)
# TimePoint(taxi_id=456, name='pick up', time=0.15)
# TimePoint(taxi_id=910, name='pick up', time=0.15)
# TimePoint(taxi_id=247, name='pick up', time=0.15)
# TimePoint(taxi_id=701, name='pick up', time=0.15)
# TimePoint(taxi_id=869, name='pick up', time=0.15)
# TimePoint(taxi_id=518, name='pick up', time=0.15)
# TimePoint(taxi_id=400, name='pick up', time=0.15)
# TimePoint(taxi_id=142, name='pick up', time=0.15)
# TimePoint(taxi_id=7, name='pick up', time=0.15)
# TimePoint(taxi_id=449, name='pick up', time=0.15)
# TimePoint(taxi_id=274, name='pick up', time=0.15)
# TimePoint(taxi_id=561, name='pick up', time=0.15)
# TimePoint(taxi_id=786, name='pick up', time=0.15)
# TimePoint(taxi_id=66, name='pick up', time=0.15)
# TimePoint(taxi_id=806, name='pick up', time=0.15)
# TimePoint(taxi_id=12, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=366, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=501, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=127, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=117, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=862, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=643, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=597, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=689, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=991, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=650, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=562, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=22, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=605, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=899, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=737, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=301, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=1, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=938, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=263, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=801, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=916, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=112, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=384, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=526, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=708, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=759, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=431, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=590, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=369, name='pick up', time=0.16666666666666666)
# TimePoint(taxi_id=46, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=4, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=707, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=589, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=593, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=310, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=42, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=428, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=80, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=914, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=805, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=781, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=352, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=195, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=656, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=814, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=430, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=131, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=790, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=743, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=418, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=684, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=59, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=603, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=652, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=162, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=462, name='pick up', time=0.18333333333333332)
# TimePoint(taxi_id=511, name='pick up', time=0.2)
# TimePoint(taxi_id=354, name='pick up', time=0.2)
# TimePoint(taxi_id=503, name='pick up', time=0.2)
# TimePoint(taxi_id=964, name='pick up', time=0.2)
# TimePoint(taxi_id=633, name='pick up', time=0.2)
# TimePoint(taxi_id=448, name='pick up', time=0.2)
# TimePoint(taxi_id=109, name='pick up', time=0.2)
# TimePoint(taxi_id=470, name='pick up', time=0.2)
# TimePoint(taxi_id=565, name='pick up', time=0.2)
# TimePoint(taxi_id=909, name='pick up', time=0.2)
# TimePoint(taxi_id=246, name='pick up', time=0.2)
# TimePoint(taxi_id=368, name='pick up', time=0.2)
# TimePoint(taxi_id=161, name='pick up', time=0.2)
# TimePoint(taxi_id=319, name='pick up', time=0.2)
# TimePoint(taxi_id=949, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=563, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=706, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=344, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=478, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=794, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=129, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=211, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=425, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=950, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=371, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=516, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=876, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=780, name='pick up', time=0.21666666666666667)
# TimePoint(taxi_id=279, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=877, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=653, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=972, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=721, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=343, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=638, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=829, name='pick up', time=0.23333333333333334)
# TimePoint(taxi_id=538, name='pick up', time=0.25)
# TimePoint(taxi_id=957, name='pick up', time=0.25)
# TimePoint(taxi_id=784, name='pick up', time=0.25)
# TimePoint(taxi_id=435, name='pick up', time=0.25)
# TimePoint(taxi_id=174, name='pick up', time=0.25)
# TimePoint(taxi_id=827, name='pick up', time=0.26666666666666666)
# TimePoint(taxi_id=184, name='pick up', time=0.26666666666666666)
# TimePoint(taxi_id=284, name='pick up', time=0.2833333333333333)
# TimePoint(taxi_id=391, name='drop off', time=0.65)
# TimePoint(taxi_id=569, name='drop off', time=0.6833333333333333)
# TimePoint(taxi_id=700, name='drop off', time=0.6833333333333333)
# TimePoint(taxi_id=694, name='drop off', time=0.7)
# TimePoint(taxi_id=970, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=175, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=69, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=297, name='drop off', time=0.7166666666666667)
# TimePoint(taxi_id=689, name='drop off', time=0.7333333333333333)
# TimePoint(taxi_id=465, name='drop off', time=0.7333333333333333)
# TimePoint(taxi_id=76, name='drop off', time=0.75)
# TimePoint(taxi_id=287, name='drop off', time=0.75)
# TimePoint(taxi_id=650, name='drop off', time=0.7666666666666666)
# TimePoint(taxi_id=241, name='drop off', time=0.7666666666666666)
# TimePoint(taxi_id=406, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=641, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=45, name='drop off', time=0.7666666666666667)
# TimePoint(taxi_id=302, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=27, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=101, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=782, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=867, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=270, name='drop off', time=0.7833333333333333)
# TimePoint(taxi_id=700, name='pick up', time=0.7833333333333333)
# TimePoint(taxi_id=320, name='drop off', time=0.7999999999999999)
# TimePoint(taxi_id=289, name='drop off', time=0.7999999999999999)
# TimePoint(taxi_id=397, name='drop off', time=0.7999999999999999)
# TimePoint(taxi_id=199, name='drop off', time=0.8)
# TimePoint(taxi_id=863, name='drop off', time=0.8)
# TimePoint(taxi_id=391, name='pick up', time=0.8)
# TimePoint(taxi_id=118, name='drop off', time=0.8)
# TimePoint(taxi_id=354, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=157, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=151, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=107, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=545, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=361, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=938, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=741, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=967, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=547, name='drop off', time=0.8166666666666667)
# TimePoint(taxi_id=75, name='drop off', time=0.8333333333333333)
# TimePoint(taxi_id=333, name='drop off', time=0.8333333333333333)
# TimePoint(taxi_id=19, name='drop off', time=0.8333333333333333)
# TimePoint(taxi_id=163, name='drop off', time=0.8333333333333333)
# TimePoint(taxi_id=816, name='drop off', time=0.8333333333333333)
# TimePoint(taxi_id=693, name='drop off', time=0.8333333333333333)
# TimePoint(taxi_id=578, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=428, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=45, name='pick up', time=0.8333333333333334)
# TimePoint(taxi_id=270, name='pick up', time=0.8333333333333334)
# TimePoint(taxi_id=686, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=447, name='drop off', time=0.8333333333333334)
# TimePoint(taxi_id=366, name='drop off', time=0.85)
# TimePoint(taxi_id=455, name='drop off', time=0.85)
# TimePoint(taxi_id=76, name='pick up', time=0.85)
# TimePoint(taxi_id=439, name='drop off', time=0.85)
# TimePoint(taxi_id=141, name='drop off', time=0.85)
# TimePoint(taxi_id=812, name='drop off', time=0.85)
# TimePoint(taxi_id=778, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=322, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=533, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=457, name='drop off', time=0.8500000000000001)
# TimePoint(taxi_id=22, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=554, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=726, name='drop off', time=0.8666666666666666)
# TimePoint(taxi_id=827, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=332, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=680, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=69, name='pick up', time=0.8666666666666667)
# TimePoint(taxi_id=565, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=520, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=937, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=319, name='drop off', time=0.8666666666666667)
# TimePoint(taxi_id=75, name='pick up', time=0.8833333333333333)
# TimePoint(taxi_id=961, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=455, name='pick up', time=0.8833333333333333)
# TimePoint(taxi_id=949, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=128, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=794, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=995, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=385, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=759, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=668, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=547, name='pick up', time=0.8833333333333333)
# TimePoint(taxi_id=590, name='drop off', time=0.8833333333333333)
# TimePoint(taxi_id=641, name='pick up', time=0.8833333333333334)
# TimePoint(taxi_id=275, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=702, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=789, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=663, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=90, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=622, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=833, name='drop off', time=0.8833333333333334)
# TimePoint(taxi_id=862, name='drop off', time=0.8999999999999999)
# TimePoint(taxi_id=689, name='pick up', time=0.8999999999999999)
# TimePoint(taxi_id=289, name='pick up', time=0.8999999999999999)
# TimePoint(taxi_id=721, name='drop off', time=0.8999999999999999)
# TimePoint(taxi_id=694, name='pick up', time=0.8999999999999999)
# TimePoint(taxi_id=215, name='drop off', time=0.9)
# TimePoint(taxi_id=302, name='pick up', time=0.9)
# TimePoint(taxi_id=461, name='drop off', time=0.9)
# TimePoint(taxi_id=426, name='drop off', time=0.9)
# TimePoint(taxi_id=80, name='drop off', time=0.9)
# TimePoint(taxi_id=129, name='drop off', time=0.9)
# TimePoint(taxi_id=101, name='pick up', time=0.9)
# TimePoint(taxi_id=784, name='drop off', time=0.9)
# TimePoint(taxi_id=569, name='pick up', time=0.9)
# TimePoint(taxi_id=915, name='drop off', time=0.9)
# TimePoint(taxi_id=93, name='drop off', time=0.9)
# TimePoint(taxi_id=131, name='drop off', time=0.9)
# TimePoint(taxi_id=73, name='drop off', time=0.9)
# TimePoint(taxi_id=297, name='pick up', time=0.9)
# TimePoint(taxi_id=457, name='pick up', time=0.9000000000000001)
# TimePoint(taxi_id=725, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=997, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=67, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=244, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=714, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=107, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=361, name='pick up', time=0.9166666666666666)
# TimePoint(taxi_id=916, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=708, name='drop off', time=0.9166666666666666)
# TimePoint(taxi_id=503, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=970, name='pick up', time=0.9166666666666667)
# TimePoint(taxi_id=322, name='pick up', time=0.9166666666666667)
# TimePoint(taxi_id=182, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=222, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=592, name='drop off', time=0.9166666666666667)
# TimePoint(taxi_id=118, name='pick up', time=0.9166666666666667)
# TimePoint(taxi_id=320, name='pick up', time=0.9333333333333332)
# TimePoint(taxi_id=650, name='pick up', time=0.9333333333333332)
# TimePoint(taxi_id=199, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=863, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=934, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=578, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=344, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=122, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=141, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=301, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=195, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=465, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=371, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=801, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=867, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=287, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=367, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=59, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=967, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=937, name='pick up', time=0.9333333333333333)
# TimePoint(taxi_id=462, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=712, name='drop off', time=0.9333333333333333)
# TimePoint(taxi_id=533, name='pick up', time=0.9333333333333335)
# TimePoint(taxi_id=127, name='drop off', time=0.95)
# TimePoint(taxi_id=27, name='pick up', time=0.95)
# TimePoint(taxi_id=478, name='drop off', time=0.95)
# TimePoint(taxi_id=157, name='pick up', time=0.95)
# TimePoint(taxi_id=605, name='drop off', time=0.95)
# TimePoint(taxi_id=175, name='pick up', time=0.95)
# TimePoint(taxi_id=241, name='pick up', time=0.95)
# TimePoint(taxi_id=733, name='drop off', time=0.95)
# TimePoint(taxi_id=880, name='drop off', time=0.95)
# TimePoint(taxi_id=46, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=71, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=853, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=914, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=90, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=177, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=456, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=680, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=400, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=120, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=560, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=319, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=751, name='drop off', time=0.9500000000000001)
# TimePoint(taxi_id=447, name='pick up', time=0.9500000000000001)
# TimePoint(taxi_id=554, name='pick up', time=0.9666666666666666)
# TimePoint(taxi_id=163, name='pick up', time=0.9666666666666666)
# TimePoint(taxi_id=693, name='pick up', time=0.9666666666666666)
# TimePoint(taxi_id=12, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=4, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=95, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=827, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=643, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=461, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=192, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=706, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=439, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=577, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=293, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=422, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=125, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=613, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=782, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=1, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=938, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=304, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=247, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=869, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=435, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=656, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=872, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=916, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=340, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=526, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=684, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=874, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=704, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=884, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=66, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=342, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=17, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=716, name='drop off', time=0.9666666666666667)
# TimePoint(taxi_id=686, name='pick up', time=0.9666666666666667)
# TimePoint(taxi_id=354, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=130, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=55, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=242, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=348, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=741, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=399, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=263, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=541, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=208, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=51, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=759, name='pick up', time=0.9833333333333333)
# TimePoint(taxi_id=369, name='drop off', time=0.9833333333333333)
# TimePoint(taxi_id=406, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=757, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=80, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=805, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=182, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=950, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=565, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=222, name='pick up', time=0.9833333333333334)
# TimePoint(taxi_id=449, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=34, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=638, name='drop off', time=0.9833333333333334)
# TimePoint(taxi_id=4, name='pick up', time=1.0)
# TimePoint(taxi_id=573, name='drop off', time=1.0)
# TimePoint(taxi_id=961, name='pick up', time=1.0)
# TimePoint(taxi_id=695, name='drop off', time=1.0)
# TimePoint(taxi_id=407, name='drop off', time=1.0)
# TimePoint(taxi_id=703, name='drop off', time=1.0)
# TimePoint(taxi_id=42, name='drop off', time=1.0)
# TimePoint(taxi_id=428, name='pick up', time=1.0)
# TimePoint(taxi_id=3, name='drop off', time=1.0)
# TimePoint(taxi_id=691, name='drop off', time=1.0)
# TimePoint(taxi_id=503, name='pick up', time=1.0)
# TimePoint(taxi_id=151, name='pick up', time=1.0)
# TimePoint(taxi_id=995, name='pick up', time=1.0)
# TimePoint(taxi_id=545, name='pick up', time=1.0)
# TimePoint(taxi_id=214, name='drop off', time=1.0)
# TimePoint(taxi_id=562, name='drop off', time=1.0)
# TimePoint(taxi_id=899, name='drop off', time=1.0)
# TimePoint(taxi_id=796, name='drop off', time=1.0)
# TimePoint(taxi_id=195, name='pick up', time=1.0)
# TimePoint(taxi_id=93, name='pick up', time=1.0)
# TimePoint(taxi_id=812, name='pick up', time=1.0)
# TimePoint(taxi_id=668, name='pick up', time=1.0)
# TimePoint(taxi_id=603, name='drop off', time=1.0)
# TimePoint(taxi_id=572, name='drop off', time=1.0)
# TimePoint(taxi_id=590, name='pick up', time=1.0)
# TimePoint(taxi_id=652, name='drop off', time=1.0)
# TimePoint(taxi_id=356, name='drop off', time=1.0)
# TimePoint(taxi_id=408, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=215, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=310, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=333, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=868, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=129, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=22, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=781, name='drop off', time=1.0166666666666666)
# TimePoint(taxi_id=397, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=721, name='pick up', time=1.0166666666666666)
# TimePoint(taxi_id=811, name='drop off', time=1.0166666666666666)
# ...
# TimePoint(taxi_id=248, name='drop off', time=23.53333333333333)
# TimePoint(taxi_id=358, name='drop off', time=23.53333333333333)
# TimePoint(taxi_id=196, name='pick up', time=23.53333333333333)
# TimePoint(taxi_id=570, name='drop off', time=23.53333333333333)
# TimePoint(taxi_id=434, name='pick up', time=23.533333333333335)
# TimePoint(taxi_id=710, name='pick up', time=23.533333333333335)
# TimePoint(taxi_id=571, name='drop off', time=23.533333333333335)
# TimePoint(taxi_id=168, name='drop off', time=23.533333333333335)
# TimePoint(taxi_id=571, name='pick up', time=23.533333333333335)
# TimePoint(taxi_id=912, name='pick up', time=23.533333333333342)
# TimePoint(taxi_id=800, name='pick up', time=23.549999999999997)
# TimePoint(taxi_id=217, name='end shift ', time=23.55)
# TimePoint(taxi_id=929, name='drop off', time=23.55)
# TimePoint(taxi_id=905, name='pick up', time=23.55)
# TimePoint(taxi_id=235, name='pick up', time=23.550000000000004)
# TimePoint(taxi_id=282, name='drop off', time=23.550000000000004)
# TimePoint(taxi_id=229, name='drop off', time=23.550000000000008)
# TimePoint(taxi_id=437, name='end shift ', time=23.55000000000001)
# TimePoint(taxi_id=167, name='pick up', time=23.550000000000015)
# TimePoint(taxi_id=996, name='pick up', time=23.550000000000015)
# TimePoint(taxi_id=97, name='drop off', time=23.55000000000002)
# TimePoint(taxi_id=746, name='end shift ', time=23.566666666666663)
# TimePoint(taxi_id=879, name='pick up', time=23.566666666666663)
# TimePoint(taxi_id=925, name='pick up', time=23.566666666666666)
# TimePoint(taxi_id=24, name='end shift ', time=23.56666666666667)
# TimePoint(taxi_id=595, name='drop off', time=23.566666666666674)
# TimePoint(taxi_id=628, name='drop off', time=23.566666666666674)
# TimePoint(taxi_id=50, name='drop off', time=23.566666666666677)
# TimePoint(taxi_id=730, name='drop off', time=23.58333333333333)
# TimePoint(taxi_id=21, name='pick up', time=23.583333333333332)
# TimePoint(taxi_id=281, name='drop off', time=23.583333333333332)
# TimePoint(taxi_id=358, name='pick up', time=23.583333333333332)
# TimePoint(taxi_id=281, name='pick up', time=23.583333333333332)
# TimePoint(taxi_id=198, name='drop off', time=23.583333333333332)
# TimePoint(taxi_id=209, name='end shift ', time=23.583333333333332)
# TimePoint(taxi_id=258, name='drop off', time=23.583333333333332)
# TimePoint(taxi_id=248, name='pick up', time=23.583333333333332)
# TimePoint(taxi_id=193, name='drop off', time=23.583333333333336)
# TimePoint(taxi_id=33, name='pick up', time=23.583333333333336)
# TimePoint(taxi_id=515, name='drop off', time=23.583333333333336)
# TimePoint(taxi_id=53, name='drop off', time=23.58333333333334)
# TimePoint(taxi_id=507, name='pick up', time=23.58333333333334)
# TimePoint(taxi_id=62, name='drop off', time=23.58333333333334)
# TimePoint(taxi_id=35, name='pick up', time=23.583333333333343)
# TimePoint(taxi_id=626, name='end shift ', time=23.583333333333343)
# TimePoint(taxi_id=212, name='pick up', time=23.599999999999994)
# TimePoint(taxi_id=983, name='pick up', time=23.599999999999994)
# TimePoint(taxi_id=28, name='end shift ', time=23.599999999999998)
# TimePoint(taxi_id=750, name='drop off', time=23.599999999999998)
# TimePoint(taxi_id=724, name='pick up', time=23.6)
# TimePoint(taxi_id=531, name='drop off', time=23.6)
# TimePoint(taxi_id=933, name='pick up', time=23.600000000000005)
# TimePoint(taxi_id=282, name='pick up', time=23.600000000000005)
# TimePoint(taxi_id=933, name='drop off', time=23.600000000000005)
# TimePoint(taxi_id=158, name='drop off', time=23.600000000000005)
# TimePoint(taxi_id=852, name='drop off', time=23.60000000000001)
# TimePoint(taxi_id=817, name='drop off', time=23.616666666666664)
# TimePoint(taxi_id=897, name='end shift ', time=23.616666666666664)
# TimePoint(taxi_id=624, name='drop off', time=23.616666666666664)
# TimePoint(taxi_id=568, name='drop off', time=23.616666666666664)
# TimePoint(taxi_id=855, name='end shift ', time=23.616666666666667)
# TimePoint(taxi_id=164, name='end shift ', time=23.61666666666667)
# TimePoint(taxi_id=971, name='drop off', time=23.616666666666678)
# TimePoint(taxi_id=197, name='drop off', time=23.63333333333333)
# TimePoint(taxi_id=959, name='drop off', time=23.633333333333333)
# TimePoint(taxi_id=750, name='pick up', time=23.633333333333333)
# TimePoint(taxi_id=662, name='end shift ', time=23.633333333333333)
# TimePoint(taxi_id=370, name='drop off', time=23.633333333333333)
# TimePoint(taxi_id=929, name='pick up', time=23.633333333333333)
# TimePoint(taxi_id=527, name='drop off', time=23.633333333333333)
# TimePoint(taxi_id=193, name='pick up', time=23.633333333333336)
# TimePoint(taxi_id=758, name='drop off', time=23.633333333333336)
# TimePoint(taxi_id=20, name='end shift ', time=23.633333333333336)
# TimePoint(taxi_id=53, name='pick up', time=23.63333333333334)
# TimePoint(taxi_id=65, name='drop off', time=23.63333333333334)
# TimePoint(taxi_id=628, name='pick up', time=23.63333333333334)
# TimePoint(taxi_id=158, name='pick up', time=23.63333333333334)
# TimePoint(taxi_id=445, name='drop off', time=23.63333333333334)
# TimePoint(taxi_id=604, name='drop off', time=23.64999999999999)
# TimePoint(taxi_id=570, name='end shift ', time=23.65)
# TimePoint(taxi_id=451, name='end shift ', time=23.65)
# TimePoint(taxi_id=198, name='pick up', time=23.65)
# TimePoint(taxi_id=16, name='drop off', time=23.650000000000006)
# TimePoint(taxi_id=832, name='end shift ', time=23.650000000000006)
# TimePoint(taxi_id=466, name='drop off', time=23.65000000000001)
# TimePoint(taxi_id=168, name='end shift ', time=23.666666666666668)
# TimePoint(taxi_id=531, name='pick up', time=23.666666666666668)
# TimePoint(taxi_id=65, name='pick up', time=23.666666666666675)
# TimePoint(taxi_id=229, name='pick up', time=23.666666666666675)
# TimePoint(taxi_id=170, name='drop off', time=23.666666666666675)
# TimePoint(taxi_id=134, name='drop off', time=23.66666666666668)
# TimePoint(taxi_id=974, name='drop off', time=23.68333333333333)
# TimePoint(taxi_id=197, name='pick up', time=23.68333333333333)
# TimePoint(taxi_id=515, name='end shift ', time=23.683333333333337)
# TimePoint(taxi_id=947, name='drop off', time=23.68333333333334)
# TimePoint(taxi_id=318, name='drop off', time=23.68333333333334)
# TimePoint(taxi_id=62, name='pick up', time=23.68333333333334)
# TimePoint(taxi_id=602, name='end shift ', time=23.683333333333344)
# TimePoint(taxi_id=847, name='drop off', time=23.683333333333344)
# TimePoint(taxi_id=50, name='pick up', time=23.683333333333344)
# TimePoint(taxi_id=97, name='pick up', time=23.68333333333335)
# TimePoint(taxi_id=758, name='pick up', time=23.700000000000003)
# TimePoint(taxi_id=595, name='pick up', time=23.700000000000006)
# TimePoint(taxi_id=530, name='drop off', time=23.700000000000006)
# TimePoint(taxi_id=947, name='pick up', time=23.700000000000006)
# TimePoint(taxi_id=16, name='pick up', time=23.700000000000006)
# TimePoint(taxi_id=971, name='pick up', time=23.70000000000001)
# TimePoint(taxi_id=61, name='drop off', time=23.70000000000001)
# TimePoint(taxi_id=26, name='drop off', time=23.716666666666658)
# TimePoint(taxi_id=49, name='drop off', time=23.716666666666665)
# TimePoint(taxi_id=111, name='drop off', time=23.716666666666665)
# TimePoint(taxi_id=88, name='drop off', time=23.716666666666665)
# TimePoint(taxi_id=258, name='pick up', time=23.716666666666665)
# TimePoint(taxi_id=500, name='drop off', time=23.716666666666665)
# TimePoint(taxi_id=822, name='drop off', time=23.716666666666672)
# TimePoint(taxi_id=349, name='drop off', time=23.716666666666672)
# TimePoint(taxi_id=225, name='drop off', time=23.73333333333333)
# TimePoint(taxi_id=568, name='pick up', time=23.73333333333333)
# TimePoint(taxi_id=924, name='drop off', time=23.73333333333333)
# TimePoint(taxi_id=999, name='drop off', time=23.73333333333333)
# TimePoint(taxi_id=974, name='pick up', time=23.73333333333333)
# TimePoint(taxi_id=571, name='drop off', time=23.733333333333334)
# TimePoint(taxi_id=360, name='drop off', time=23.733333333333338)
# TimePoint(taxi_id=92, name='drop off', time=23.733333333333338)
# TimePoint(taxi_id=768, name='drop off', time=23.73333333333334)
# TimePoint(taxi_id=318, name='pick up', time=23.73333333333334)
# TimePoint(taxi_id=134, name='pick up', time=23.733333333333345)
# TimePoint(taxi_id=669, name='drop off', time=23.749999999999993)
# TimePoint(taxi_id=624, name='pick up', time=23.749999999999996)
# TimePoint(taxi_id=225, name='pick up', time=23.749999999999996)
# TimePoint(taxi_id=858, name='drop off', time=23.75)
# TimePoint(taxi_id=111, name='pick up', time=23.75)
# TimePoint(taxi_id=749, name='drop off', time=23.75)
# TimePoint(taxi_id=329, name='drop off', time=23.75)
# TimePoint(taxi_id=230, name='drop off', time=23.750000000000004)
# TimePoint(taxi_id=445, name='pick up', time=23.750000000000007)
# TimePoint(taxi_id=852, name='end shift ', time=23.750000000000007)
# TimePoint(taxi_id=530, name='pick up', time=23.750000000000007)
# TimePoint(taxi_id=817, name='end shift ', time=23.766666666666662)
# TimePoint(taxi_id=523, name='drop off', time=23.766666666666666)
# TimePoint(taxi_id=959, name='pick up', time=23.766666666666666)
# TimePoint(taxi_id=500, name='pick up', time=23.766666666666666)
# TimePoint(taxi_id=464, name='drop off', time=23.766666666666666)
# TimePoint(taxi_id=137, name='drop off', time=23.76666666666667)
# TimePoint(taxi_id=360, name='pick up', time=23.766666666666673)
# TimePoint(taxi_id=200, name='drop off', time=23.766666666666673)
# TimePoint(taxi_id=61, name='pick up', time=23.766666666666676)
# TimePoint(taxi_id=882, name='drop off', time=23.76666666666668)
# TimePoint(taxi_id=730, name='end shift ', time=23.783333333333328)
# TimePoint(taxi_id=370, name='pick up', time=23.78333333333333)
# TimePoint(taxi_id=464, name='pick up', time=23.78333333333333)
# TimePoint(taxi_id=588, name='drop off', time=23.783333333333335)
# TimePoint(taxi_id=349, name='pick up', time=23.78333333333334)
# TimePoint(taxi_id=609, name='drop off', time=23.783333333333342)
# TimePoint(taxi_id=466, name='end shift ', time=23.783333333333342)
# TimePoint(taxi_id=847, name='pick up', time=23.783333333333346)
# TimePoint(taxi_id=26, name='pick up', time=23.79999999999999)
# TimePoint(taxi_id=557, name='drop off', time=23.799999999999997)
# TimePoint(taxi_id=527, name='end shift ', time=23.8)
# TimePoint(taxi_id=858, name='pick up', time=23.8)
# TimePoint(taxi_id=383, name='drop off', time=23.8)
# TimePoint(taxi_id=329, name='pick up', time=23.8)
# TimePoint(taxi_id=896, name='drop off', time=23.800000000000008)
# TimePoint(taxi_id=188, name='drop off', time=23.800000000000008)
# TimePoint(taxi_id=532, name='drop off', time=23.81666666666666)
# TimePoint(taxi_id=980, name='drop off', time=23.816666666666663)
# TimePoint(taxi_id=49, name='pick up', time=23.816666666666666)
# TimePoint(taxi_id=788, name='drop off', time=23.816666666666666)
# TimePoint(taxi_id=105, name='drop off', time=23.816666666666666)
# TimePoint(taxi_id=230, name='end shift ', time=23.81666666666667)
# TimePoint(taxi_id=822, name='pick up', time=23.816666666666674)
# TimePoint(taxi_id=170, name='end shift ', time=23.816666666666674)
# TimePoint(taxi_id=768, name='pick up', time=23.816666666666674)
# TimePoint(taxi_id=412, name='drop off', time=23.83333333333333)
# TimePoint(taxi_id=629, name='drop off', time=23.833333333333332)
# TimePoint(taxi_id=557, name='pick up', time=23.833333333333332)
# TimePoint(taxi_id=571, name='pick up', time=23.833333333333336)
# TimePoint(taxi_id=137, name='pick up', time=23.833333333333336)
# TimePoint(taxi_id=194, name='drop off', time=23.83333333333334)
# TimePoint(taxi_id=882, name='pick up', time=23.833333333333346)
# TimePoint(taxi_id=994, name='drop off', time=23.833333333333346)
# TimePoint(taxi_id=611, name='drop off', time=23.849999999999994)
# TimePoint(taxi_id=299, name='drop off', time=23.85)
# TimePoint(taxi_id=788, name='pick up', time=23.85)
# TimePoint(taxi_id=235, name='drop off', time=23.850000000000005)
# TimePoint(taxi_id=494, name='drop off', time=23.850000000000005)
# TimePoint(taxi_id=200, name='pick up', time=23.850000000000005)
# TimePoint(taxi_id=188, name='pick up', time=23.85000000000001)
# TimePoint(taxi_id=357, name='drop off', time=23.850000000000012)
# TimePoint(taxi_id=654, name='drop off', time=23.850000000000012)
# TimePoint(taxi_id=604, name='end shift ', time=23.86666666666666)
# TimePoint(taxi_id=88, name='end shift ', time=23.866666666666664)
# TimePoint(taxi_id=980, name='pick up', time=23.866666666666664)
# TimePoint(taxi_id=543, name='drop off', time=23.866666666666667)
# TimePoint(taxi_id=629, name='pick up', time=23.866666666666667)
# TimePoint(taxi_id=749, name='end shift ', time=23.866666666666667)
# TimePoint(taxi_id=925, name='drop off', time=23.866666666666667)
# TimePoint(taxi_id=933, name='drop off', time=23.86666666666667)
# TimePoint(taxi_id=619, name='drop off', time=23.86666666666667)
# TimePoint(taxi_id=611, name='pick up', time=23.88333333333333)
# TimePoint(taxi_id=999, name='end shift ', time=23.88333333333333)
# TimePoint(taxi_id=523, name='end shift ', time=23.883333333333333)
# TimePoint(taxi_id=905, name='drop off', time=23.883333333333333)
# TimePoint(taxi_id=194, name='pick up', time=23.88333333333334)
# TimePoint(taxi_id=673, name='drop off', time=23.88333333333334)
# TimePoint(taxi_id=669, name='end shift ', time=23.899999999999995)
# TimePoint(taxi_id=932, name='drop off', time=23.899999999999995)
# TimePoint(taxi_id=510, name='drop off', time=23.9)
# TimePoint(taxi_id=905, name='pick up', time=23.9)
# TimePoint(taxi_id=630, name='drop off', time=23.900000000000002)
# TimePoint(taxi_id=483, name='drop off', time=23.900000000000006)
# TimePoint(taxi_id=896, name='end shift ', time=23.90000000000001)
# TimePoint(taxi_id=654, name='pick up', time=23.900000000000013)
# TimePoint(taxi_id=879, name='drop off', time=23.916666666666664)
# TimePoint(taxi_id=543, name='pick up', time=23.916666666666668)
# TimePoint(taxi_id=821, name='drop off', time=23.916666666666668)
# TimePoint(taxi_id=235, name='pick up', time=23.91666666666667)
# TimePoint(taxi_id=433, name='drop off', time=23.91666666666667)
# TimePoint(taxi_id=483, name='pick up', time=23.91666666666667)
# TimePoint(taxi_id=357, name='pick up', time=23.91666666666668)
# TimePoint(taxi_id=924, name='end shift ', time=23.93333333333333)
# TimePoint(taxi_id=299, name='pick up', time=23.933333333333334)
# TimePoint(taxi_id=925, name='pick up', time=23.933333333333334)
# TimePoint(taxi_id=494, name='pick up', time=23.933333333333337)
# TimePoint(taxi_id=193, name='drop off', time=23.933333333333337)
# TimePoint(taxi_id=619, name='pick up', time=23.933333333333337)
# TimePoint(taxi_id=912, name='drop off', time=23.93333333333334)
# TimePoint(taxi_id=596, name='drop off', time=23.94999999999999)
# TimePoint(taxi_id=532, name='end shift ', time=23.949999999999992)
# TimePoint(taxi_id=264, name='drop off', time=23.949999999999996)
# TimePoint(taxi_id=383, name='end shift ', time=23.95)
# TimePoint(taxi_id=266, name='drop off', time=23.95)
# TimePoint(taxi_id=535, name='drop off', time=23.950000000000003)
# TimePoint(taxi_id=33, name='drop off', time=23.950000000000003)
# TimePoint(taxi_id=40, name='drop off', time=23.950000000000006)
# TimePoint(taxi_id=229, name='drop off', time=23.95000000000001)
# TimePoint(taxi_id=983, name='drop off', time=23.96666666666666)
# TimePoint(taxi_id=800, name='drop off', time=23.966666666666665)
# TimePoint(taxi_id=531, name='drop off', time=23.96666666666667)
# TimePoint(taxi_id=463, name='drop off', time=23.966666666666676)
# TimePoint(taxi_id=229, name='pick up', time=23.966666666666676)
# TimePoint(taxi_id=412, name='end shift ', time=23.983333333333327)
# TimePoint(taxi_id=248, name='drop off', time=23.98333333333333)
# TimePoint(taxi_id=879, name='pick up', time=23.98333333333333)
# TimePoint(taxi_id=266, name='pick up', time=23.983333333333334)
# TimePoint(taxi_id=821, name='pick up', time=23.983333333333334)
# TimePoint(taxi_id=92, name='end shift ', time=23.983333333333338)
# TimePoint(taxi_id=193, name='pick up', time=23.983333333333338)
# TimePoint(taxi_id=53, name='drop off', time=23.98333333333334)
# TimePoint(taxi_id=996, name='drop off', time=23.98333333333335)
# TimePoint(taxi_id=264, name='pick up', time=23.999999999999996)
# TimePoint(taxi_id=434, name='drop off', time=24.0)

# %%
np.random.normal(loc=30, scale=2)
# Out:
# 28.784417595333252
