# %%
#import rpy2
#%load_ext rpy2.ipython
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt 
import seaborn as sns 
from pylab import rcParams
from statsmodels.graphics.tsaplots import month_plot
from mpl_toolkits.mplot3d import Axes3D

# %%
# Python

# 정규분포를 따르는 난수 100개 추출
mu = 0
sd = 10
size = 100

np.random.seed(100)
n = np.random.normal(mu, sd, size) + range(100)

# 데이터 프레임 만들기
data = pd.DataFrame(n)

# 그래프 그리기
plt.plot(n)
plt.plot(data.rolling(window=5).mean())
plt.plot(data.rolling(window=50, center=True).mean())

# %%
plt.plot(n)
plt.plot(data.rolling(window=20, min_periods=0).apply(min))
plt.plot(data.rolling(window=pd.api.indexers.FixedForwardWindowIndexer(window_size=20), min_periods=0).apply(min))

# %%
plt.plot(n)
plt.plot(data.expanding(0).apply(max))
plt.plot(data.expanding(0).apply(np.mean))

# %%
import statsmodels.graphics.tsaplots as sgt

# %%
# Python

# sin 함수 만들기 
x = np.linspace(1, 100, 100)
y = np.sin(x * np.pi / 3)

# sin 그래프와 ACF 그래프 그리기
plt.plot(y[:30])
sgt.plot_acf(y, adjusted=True)

plt.show()

# %%
# Python

# sin 함수 만들기
y = np.sin(x * np.pi / 3)

# sin 그래프와 PACF 그래프 그리기
plt.plot(y[:30])
sgt.plot_pacf(y, lags=30, method='ywm')

plt.show()

# %%
# Python

# sin 함수 만들기
y1 = np.sin(x * np.pi / 3)

# sin 그래프와 PACF 그래프 그리기
plt.plot(y1)
sgt.plot_acf(y1, adjusted=True)
sgt.plot_pacf(y1, lags=30, method='ywm')

plt.show()

# %%
# Python

# sin 함수 만들기
y2 = np.sin(x * np.pi / 10)

# sin 그래프와 PACF 그래프 그리기
plt.plot(y2)
sgt.plot_acf(y2, adjusted=True)
sgt.plot_pacf(y2, lags=30, method='ywm')

plt.show()

# %%
y3 = y1 + y2

plt.plot(y3[:30])
sgt.plot_acf(y3, adjusted=True)
sgt.plot_pacf(y3, lags=30, method='ywm')

plt.show()

# %%
plt.plot(x[:30])
sgt.plot_acf(x, adjusted=True)
sgt.plot_pacf(x, lags=30, method='ywm')

plt.show()

# %%
import plotly.express as px

# %%
donations = pd.read_csv('../Ch02/data/donations.csv')

# %%
d = donations.groupby('user').timestamp.agg(['min', 'max']).reset_index()
d.columns = ['user', 'start', 'end']
df = d[d.start != d.end]
df
# Out:
#       user                start                  end
# 0      0.0  2015-12-25 15:18:16  2018-02-14 18:47:34
# 1      1.0  2015-12-30 11:48:08  2018-05-27 18:53:10
# 2      2.0  2016-05-30 17:54:55  2017-12-22 14:11:15
# 3      3.0  2016-03-12 21:53:58  2016-12-29 11:00:27
# 5      7.0  2016-01-26 13:57:31  2017-04-16 16:47:13
# ..     ...                  ...                  ...
# 553  994.0  2017-06-05 13:29:03  2017-09-18 16:03:11
# 554  995.0  2017-05-03 17:18:46  2018-05-07 17:09:36
# 555  996.0  2016-08-08 21:06:04  2016-10-25 11:37:28
# 556  997.0  2017-11-10 20:20:53  2018-05-24 16:32:32
# 557  998.0  2017-11-12 18:57:35  2018-01-07 11:28:16
#
# [473 rows x 3 columns]

# %%
df = df.astype({'user': 'int'})
df = df.astype({'start': 'datetime64[ns]', 'end': 'datetime64[ns]', 'user': 'str'})

# %%
import plotly.express as px
import plotly.io as pio
import plotly
#pio.renderers = 'jupyterlab'


fig = px.timeline(df[:20], x_start="start", x_end="end", y="user")
fig.update_yaxes(autorange="reversed") # otherwise tasks are listed from the bottom up

fig.show(renderer="png")

# %%
# Python
# 가로 막대 그래프

df = pd.DataFrame(np.random.randn(4,4))
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# Python
# lineplot

flights = sns.load_dataset("flights")

sns.lineplot(data=flights, 
             x='month', 
             y='passengers', 
             hue='year', 
             legend='full')

plt.title('Seasonal plot')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2);

# %%
# Python
# plt.plot()

AirPassengers = pd.read_csv('dataset/AirPassengers.csv', names=['Month', 'AirPassengers'])

plt.plot(np.arange(0, 12), np.mat(AirPassengers['AirPassengers'].values.reshape(12,12)),
         linestyle = '-', linewidth = 2.5)

plt.show()

# %%
# Python
# month_plot

AirPassengers.Month = pd.to_datetime(AirPassengers.Month)
AirPassengers = AirPassengers.set_index('Month')

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
month_plot(AirPassengers['AirPassengers'],ylabel='AirPassengers')
plt.grid();

# %%
# Python
# Heatmap

arr = AirPassengers['AirPassengers'].values.reshape(12,12).transpose()


passenger = []

for i in range(arr.shape[0]):
    for j in range(arr.shape[1]):
        for k in range(arr[i][j]):
            passenger.append([i, j])

passenger = np.array(passenger)

plt.hist2d(passenger[:, 0], passenger[:, 1], bins=[12, 5])
plt.colorbar(shrink=0.8, aspect=10)
#plt.clim(-1.0, 1.0)

plt.show()

# %%
fiftywords = pd.read_csv('dataset/50words_TEST.csv', header=None)

# %%
fiftywords = fiftywords[fiftywords[0] == 1].values[:,1:]

# %%
arr = fiftywords

# %%
arr.shape[1]
# Out:
# 270

# %%
words = []

for i in range(arr.shape[0]):
    for j in range(arr.shape[1]):
        words.append([arr[i][j], j])

words = np.array(words)

plt.hist2d(words[:, 1], words[:, 0], bins=[arr.shape[1], 25])
plt.colorbar(shrink=0.8, aspect=10)
#plt.clim(-1.0, 1.0)

plt.show()

# %%
# Python
# hexbin

with sns.axes_style("white"):
    sns.jointplot(x=words[:, 1], y=words[:, 0], kind="hex", color="k")

# %%
# 3D scatter plot

n = 100
xmin, xmax, ymin, ymax, zmin, zmax = 0, 20, 0, 20, 0, 50
cmin, cmax = 0, 2

xs = np.array([(xmax - xmin) * np.random.random_sample() + xmin for i in range(n)])
ys = np.array([(ymax - ymin) * np.random.random_sample() + ymin for i in range(n)])
zs = np.array([(zmax - zmin) * np.random.random_sample() + zmin for i in range(n)])
color = np.array([(cmax - cmin) * np.random.random_sample() + cmin for i in range(n)])

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c=color, marker='o', s=15, cmap='Greens')

plt.show()

# %%
# Python
# 3d contour plot

x = np.linspace(-10, 10, 100)
y = np.linspace(-15, 15, 100)

X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)

fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 100, cmap = 'viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

rs = np.random.RandomState()
rs.seed(0)

def brownian_motion(T = 1, N = 100, mu = 0.1, sigma = 0.01, S0 = 20):
    dt = float(T)/N
    t = np.linspace(0, T, N)
    W = rs.standard_normal(size = N)
    W = np.cumsum(W)*np.sqrt(dt) # standard brownian motion
    X = (mu-0.5*sigma**2)*t + sigma*W
    S = S0*np.exp(X) # geometric brownian motion
    return S

dates = pd.date_range('2012-01-01', '2013-02-22')
T = (dates.max()-dates.min()).days / 365
N = dates.size
start_price = 100
y = brownian_motion(T, N, sigma=0.1, S0=start_price)
z = brownian_motion(T, N, sigma=0.1, S0=start_price)

fig = go.Figure(data=go.Scatter3d(
    x=dates, y=y, z=z,
    marker=dict(
        size=4,
        color=z,
        colorscale='Viridis',
    ),
    line=dict(
        color='darkblue',
        width=2
    )
))

fig.update_layout(
    width=800,
    height=700,
    autosize=False,
    scene=dict(
        camera=dict(
            up=dict(
                x=0,
                y=0,
                z=1
            ),
            eye=dict(
                x=0,
                y=1.0707,
                z=1,
            )
        ),
        aspectratio = dict( x=1, y=1, z=0.7 ),
        aspectmode = 'manual'
    ),
)

plotly.offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
line_data = pd.read_csv('dataset/50words_TEST.csv', header=None)
